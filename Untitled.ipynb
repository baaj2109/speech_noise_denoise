# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import glob
import librosa.display
import IPython.display as ipd

import tensorflow as tf
from tensorflow import keras

# %%
print(f"current dir: {os.getcwd()}")
# Out:
# current dir: /Users/kehwaweng/Documents/speech_denoise/noise_reduction

# %%
# model = keras.models.load_model("./1_st/NoiseSuppressionModel.h5")
# model = keras.models.load_model("./2_nd/NoiseSuppressionModel.h5")
model = keras.models.load_model("/Users/kehwaweng/Documents/speech_denoise/speech_denoise/output_temp/20210217-100959/models/epoch-183-loss-0.016228.h5")
model.summary()
# Out:
# Model: "functional_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 12000, 1)]   0
# __________________________________________________________________________________________________
# conv1d (Conv1D)                 (None, 6000, 2)      66          input_1[0][0]
# __________________________________________________________________________________________________
# conv1d_1 (Conv1D)               (None, 3000, 4)      260         conv1d[0][0]
# __________________________________________________________________________________________________
# conv1d_2 (Conv1D)               (None, 1500, 8)      1032        conv1d_1[0][0]
# __________________________________________________________________________________________________
# conv1d_3 (Conv1D)               (None, 750, 16)      4112        conv1d_2[0][0]
# __________________________________________________________________________________________________
# conv1d_4 (Conv1D)               (None, 375, 32)      16416       conv1d_3[0][0]
# __________________________________________________________________________________________________
# conv1d_transpose (Conv1DTranspo (None, 375, 32)      32800       conv1d_4[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 375, 64)      0           conv1d_4[0][0]
#                                                                  conv1d_transpose[0][0]
# __________________________________________________________________________________________________
# conv1d_transpose_1 (Conv1DTrans (None, 750, 16)      32784       concatenate[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 750, 32)      0           conv1d_3[0][0]
#                                                                  conv1d_transpose_1[0][0]
# __________________________________________________________________________________________________
# conv1d_transpose_2 (Conv1DTrans (None, 1500, 8)      8200        concatenate_1[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 1500, 16)     0           conv1d_2[0][0]
#                                                                  conv1d_transpose_2[0][0]
# __________________________________________________________________________________________________
# conv1d_transpose_3 (Conv1DTrans (None, 3000, 4)      2052        concatenate_2[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 3000, 8)      0           conv1d_1[0][0]
#                                                                  conv1d_transpose_3[0][0]
# __________________________________________________________________________________________________
# conv1d_transpose_4 (Conv1DTrans (None, 6000, 2)      514         concatenate_3[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 6000, 4)      0           conv1d[0][0]
#                                                                  conv1d_transpose_4[0][0]
# __________________________________________________________________________________________________
# conv1d_transpose_5 (Conv1DTrans (None, 12000, 1)     129         concatenate_4[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 12000, 2)     0           input_1[0][0]
#                                                                  conv1d_transpose_5[0][0]
# __________________________________________________________________________________________________
# conv1d_transpose_6 (Conv1DTrans (None, 12000, 1)     65          concatenate_5[0][0]
# ==================================================================================================
# Total params: 98,430
# Trainable params: 98,430
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
clean_sounds = glob.glob('/Volumes/IPEVO_X0244/speech_to_text/speech_to_text_dataset/facebookresearch/train/clean_trainset_wav/*')
noisy_sounds = glob.glob('/Volumes/IPEVO_X0244/speech_to_text/speech_to_text_dataset/facebookresearch/train/noisy_trainset_wav/*')

# %%
batching_size = 12000

# %%
def get_audio(path):
    audio,_ = tf.audio.decode_wav(tf.io.read_file(path),1)
    return audio

# %%
def inference_preprocess(path):
    audio = get_audio(path)
    audio_len = audio.shape[0]
    batches = []
    for i in range(0,audio_len-batching_size,batching_size):
        batches.append(audio[i:i+batching_size])

    batches.append(audio[-batching_size:])
    diff = audio_len - (i + batching_size)
    return tf.stack(batches), diff

# %%
def predict(path):
    test_data,diff = inference_preprocess(path)
    predictions = model.predict(test_data)
    final_op = tf.reshape(predictions[:-1],((predictions.shape[0]-1)*predictions.shape[1],1))
    final_op = tf.concat((final_op,predictions[-1][-diff:]),axis=0)
    return final_op

# %%
selected_index = np.random.choice(range(len(noisy_sounds)))
print(f"selected index : {selected_index}")
# Out:
# selected index : 6628

# %%
ipd.Audio(np.squeeze(get_audio(noisy_sounds[selected_index]).numpy(),-1), rate = 16000)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
ipd.Audio(tf.squeeze(predict(noisy_sounds[selected_index])), rate= 16000)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# librosa.display.waveplot(np.squeeze(get_audio(clean_sounds[selected_index]).numpy(),-1))
librosa.display.waveplot(np.squeeze(get_audio(noisy_sounds[selected_index]).numpy(),-1))

librosa.display.waveplot(np.squeeze(predict(noisy_sounds[selected_index])))

# %%
selected_path = np.random.choice(noisy_sounds)
print(f"select path : {selected_path}")
# Out:
# select path : /Volumes/IPEVO_X0244/speech_to_text/speech_to_text_dataset/facebookresearch/train/noisy_trainset_wav/p228_248.wav

# %%
tf_audio,_ = tf.audio.decode_wav(tf.io.read_file(selected_path),1)
print(tf_audio.shape)
# Out:
# (31040, 1)

# %%
tf_audio.numpy()
# Out:
# array([[-0.07620239],
#        [-0.11819458],
#        [-0.11401367],
#        ...,
#        [ 0.12191772],
#        [ 0.10263062],
#        [ 0.10354614]], dtype=float32)

# %%
wave, sr = librosa.load(selected_path, sr = None)
print(wave.shape)
print(sr)
# Out:
# (31040,)
# 16000
